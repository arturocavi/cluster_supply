# %%
import pandas as pd

denue = pd.read_csv('denue_inegi_14_.csv',index_col=False, encoding='latin-1')

denue.head()
# Out:
# C:\Users\arturo.carrillo\AppData\Local\Temp\ipykernel_22840\229190722.py:3: DtypeWarning: Columns (35) have mixed types. Specify dtype option on import or set low_memory=False.
#   denue = pd.read_csv('denue_inegi_14_.csv',index_col=False, encoding='latin-1')
#         id                          clee                 nom_estab  \
# 0  8624390  14120112512000022000000000O3   ACUACULTORES LOS CASTRO
# 1  8838371  14039112511000014000000000O4  ACUACULTURA DEL PACIFICO
# 2  9233864  14095112512000022000000000O7        ACUIC0LA LA CABAÑA
# 3  8341990  14095114119000082000000000O3  ACUICOLA DE VILLA CORONA
# 4  8908807  14079112512000011000000000U4       ACUÍCOLA EL DURAZNO
#
#                                raz_social  codigo_act  \
# 0  ACUACULTORES LOS CASTRO SC DE RL DE CV      112512
# 1               ACUACULTURA DEL PACIFICO       112511
# 2                                     NaN      112512
# 3               ACUICOLA DE VILLA CORONA       112512
# 4                                     NaN      112512
#
#                                           nombre_act           per_ocu  \
# 0  Piscicultura y otra acuicultura, excepto camar...    0 a 5 personas
# 1                                    Camaronicultura  11 a 30 personas
# 2  Piscicultura y otra acuicultura, excepto camar...    0 a 5 personas
# 3  Piscicultura y otra acuicultura, excepto camar...   6 a 10 personas
# 4  Piscicultura y otra acuicultura, excepto camar...    0 a 5 personas
#
#   tipo_vial        nom_vial tipo_v_e_1  ...  \
# 0  CIRCUITO    DE LAS CAÑAS      CALLE  ...
# 1     CALLE    PABLO VALDEZ      CALLE  ...
# 2     CALLE     HIDALGO SUR      CALLE  ...
# 3     CALLE         ALLENDE      CALLE  ...
# 4       NaN  SIN REFERENCIA        NaN  ...
#
#                                            localidad  ageb manzana  \
# 0  Campestre las Palomas [Fraccionamiento]       ...  6940      13
# 1  Guadalajara                                   ...  1170       3
# 2  Teuchitlán                                    ...  010A       8
# 3  Villa Corona                                  ...  0075      14
# 4  El Durazno                                    ...  006A     800
#
#        telefono                  correoelec  www tipoUniEco    latitud  \
# 0  3317429415.0          ELDOTE@HOTMAIL.COM  NaN       Fijo  20.820661
# 1           NaN  CONSTRULOGA@PRODIGY.NET.MX  NaN       Fijo  20.681686
# 2  3841193710.0                         NaN  NaN       Fijo  20.683360
# 3  3331052902.0                         NaN  NaN       Fijo  20.418737
# 4           NaN                         NaN  NaN       Fijo  19.853656
#
#      longitud  fecha_alta
# 0 -103.446726     2019-11
# 1 -103.329962     2019-11
# 2 -103.849741     2020-04
# 3 -103.666418     2019-11
# 4 -103.346905     2019-11
#
# [5 rows x 42 columns]

# %%
actividades = pd.read_excel('clusters_actividades.xlsx', sheet_name='actividades')

actividades.head()
# Out:
#    id_act                                          actividad
# 0  314110                Fabricación de alfombras y tapetes
# 1  321920  Fabricación de productos para embalaje y envas...
# 2  322210                  Fabricación de envases de cartón
# 3  323119    Impresión de formas continuas y otros impresos
# 4  324191       Fabricación de aceites y grasas lubricantes

# %%
denue.columns
# Out:
# Index(['id', 'clee', 'nom_estab', 'raz_social', 'codigo_act', 'nombre_act',
#        'per_ocu', 'tipo_vial', 'nom_vial', 'tipo_v_e_1', 'nom_v_e_1',
#        'tipo_v_e_2', 'nom_v_e_2', 'tipo_v_e_3', 'nom_v_e_3', 'numero_ext',
#        'letra_ext', 'edificio', 'edificio_e', 'numero_int', 'letra_int',
#        'tipo_asent', 'nomb_asent', 'tipoCenCom', 'nom_CenCom', 'num_local',
#        'cod_postal', 'cve_ent', 'entidad', 'cve_mun', 'municipio', 'cve_loc',
#        'localidad', 'ageb', 'manzana', 'telefono', 'correoelec', 'www',
#        'tipoUniEco', 'latitud', 'longitud', 'fecha_alta'],
#       dtype='object')

# %%
# Selección de variables del DENUE
datos = denue['id nom_estab raz_social codigo_act per_ocu telefono correoelec www nom_vial numero_ext cve_mun municipio latitud longitud'.split()]
datos = denue['id nom_estab raz_social codigo_act per_ocu telefono correoelec www nom_vial numero_ext cve_mun latitud longitud'.split()]

# Formato de letras mayúsculas
datos['nom_estab raz_social nom_vial municipio'.split()] = datos['nom_estab raz_social nom_vial municipio'.split()].apply(lambda x: x.str.title())
datos['correoelec www'.split()] = datos['correoelec www'.split()].apply(lambda x: x.str.lower())

datos.head()
# Out:
# C:\Users\arturo.carrillo\AppData\Local\Temp\ipykernel_22840\3554577468.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['nom_estab raz_social nom_vial municipio'.split()] = datos['nom_estab raz_social nom_vial municipio'.split()].apply(lambda x: x.str.title())
# C:\Users\arturo.carrillo\AppData\Local\Temp\ipykernel_22840\3554577468.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos['correoelec www'.split()] = datos['correoelec www'.split()].apply(lambda x: x.str.lower())
#         id                 nom_estab                              raz_social  \
# 0  8624390   Acuacultores Los Castro  Acuacultores Los Castro Sc De Rl De Cv
# 1  8838371  Acuacultura Del Pacifico               Acuacultura Del Pacifico
# 2  9233864        Acuic0La La Cabaña                                     NaN
# 3  8341990  Acuicola De Villa Corona               Acuicola De Villa Corona
# 4  8908807       Acuícola El Durazno                                     NaN
#
#    codigo_act           per_ocu      telefono                  correoelec  \
# 0      112512    0 a 5 personas  3317429415.0          eldote@hotmail.com
# 1      112511  11 a 30 personas           NaN  construloga@prodigy.net.mx
# 2      112512    0 a 5 personas  3841193710.0                         NaN
# 3      112512   6 a 10 personas  3331052902.0                         NaN
# 4      112512    0 a 5 personas           NaN                         NaN
#
#    www        nom_vial  numero_ext  cve_mun     municipio    latitud  \
# 0  NaN    De Las Cañas        71.0      120       Zapopan  20.820661
# 1  NaN    Pablo Valdez       606.0       39   Guadalajara  20.681686
# 2  NaN     Hidalgo Sur        66.0       95    Teuchitlán  20.683360
# 3  NaN         Allende        76.0      114  Villa Corona  20.418737
# 4  NaN  Sin Referencia         NaN       79  Gómez Farías  19.853656
#
#      longitud
# 0 -103.446726
# 1 -103.329962
# 2 -103.849741
# 3 -103.666418
# 4 -103.346905

# %%
# Filtrar actividades de clusters
datos = datos[datos['codigo_act'].isin(actividades['id_act'])]
datos.shape
# Out:
# (17197, 14)

# %%
# Exportar a CSV
datos.to_csv('denue_csv.csv', index=False, encoding="cp1252")

# Exportar a Excel
#datos.to_excel('datos_denue_excel.xlsx', index=False)
